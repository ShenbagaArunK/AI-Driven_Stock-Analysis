# %% [markdown]
# ## We will pick our random 50 stocks from this list of Nifty 500 stocks which has equal weigthed distribution so that there wont be any bias. Then the remaining 5 ETFs will be added manually

# %%
pip install yfinance pandas sqlalchemy mysql-connector-python
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------------- -------------------- 0.8/1.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------- -------------- 1.0/1.6 MB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 1.9 MB/s eta 0:00:01
#    -------------------------------- ------- 1.3/1.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 1.3 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/16.5 MB ? eta -:--:--
# ...

# %%
import pandas as pd
import yfinance as yf
import time

# %%
## Importing our stcok list data
df = pd.read_csv(r"C:\Users\ilaky\Documents\DataScience\AI-Driven_Multi-Asset-Intelligence_&_Portfolio-Engine\data\ind_nifty500list.csv")

## Formating stock ticker to yfinance approved format [adding .NS]
df["Ticker"] = df["Symbol"] + ".NS"

## Fetching each Stocks MarketCap

# %%
df
# Out:
#                            Company Name                           Industry  \
# 0                      360 ONE WAM Ltd.                 Financial Services
# 1                         3M India Ltd.                        Diversified
# 2                        ABB India Ltd.                      Capital Goods
# 3                              ACC Ltd.             Construction Materials
# 4              ACME Solar Holdings Ltd.                              Power
# ..                                  ...                                ...
# 496  Zee Entertainment Enterprises Ltd.  Media Entertainment & Publication
# 497               Zen Technologies Ltd.                      Capital Goods
# 498             Zensar Technolgies Ltd.             Information Technology
# 499             Zydus Lifesciences Ltd.                         Healthcare
# 500                eClerx Services Ltd.                           Services
#
#          Symbol Series     ISIN Code         Ticker
# ...

# %%
df["Industry"].value_counts()
# Out:
# Industry
# Financial Services                   95
# Capital Goods                        64
# Healthcare                           52
# Automobile and Auto Components       35
# Fast Moving Consumer Goods           31
# Information Technology               28
# Chemicals                            26
# Consumer Services                    26
# Oil Gas & Consumable Fuels           19
# Consumer Durables                    19
# Power                                18
# Metals & Mining                      17
# Services                             14
# Construction                         12
# Construction Materials               11
# Realty                               10
# Telecommunication                    10
# Textiles                              6
# Media Entertainment & Publication     4
# Diversified                           3
# Forest Materials                      1
# Name: count, dtype: int64

# %%
df["Industry"].unique()
# Out:
# <ArrowStringArray>
# [               'Financial Services',                       'Diversified',
#                      'Capital Goods',            'Construction Materials',
#                              'Power',        'Fast Moving Consumer Goods',
#                          'Chemicals',                        'Healthcare',
#                    'Metals & Mining',                          'Services',
#         'Oil Gas & Consumable Fuels',                 'Consumer Services',
#                   'Forest Materials',                      'Construction',
#             'Information Technology',                 'Consumer Durables',
#                           'Textiles',    'Automobile and Auto Components',
#                             'Realty',                 'Telecommunication',
#  'Media Entertainment & Publication']
# Length: 21, dtype: str

# %%
df[df["Industry"] == "Diversified"]
# Out:
#                Company Name     Industry      Symbol Series     ISIN Code  \
# 1             3M India Ltd.  Diversified     3MINDIA     EQ  INE470A01017
# 134        DCM Shriram Ltd.  Diversified  DCMSHRIRAM     EQ  INE499A01024
# 187  Godrej Industries Ltd.  Diversified   GODREJIND     EQ  INE233A01035
#
#             Ticker
# 1       3MINDIA.NS
# 134  DCMSHRIRAM.NS
# 187   GODREJIND.NS

# %%
exide = yf.Ticker("EXIDEIND.NS")

# %%
exide.info
# Out:
# {'address1': 'Exide House',
#  'address2': '59E Chowringhee Road',
#  'city': 'Kolkata',
#  'zip': '700020',
#  'country': 'India',
#  'phone': '91 33 2302 3400',
#  'fax': '91 33 2283 2637',
#  'website': 'https://www.exideindustries.com',
#  'industry': 'Auto Parts',
#  'industryKey': 'auto-parts',
#  'industryDisp': 'Auto Parts',
#  'sector': 'Consumer Cyclical',
#  'sectorKey': 'consumer-cyclical',
#  'sectorDisp': 'Consumer Cyclical',
# ...

# %%
cap = exide.info.get('marketCap')

# %%
cap
# Out:
# 268759187456

# %%
sector = exide.info.get('sector')

# %%
sector
# Out:
# 'Consumer Cyclical'

# %%
cap = exide.info.get('sector','marketCap')

# %%
cap
# Out:
# 'Consumer Cyclical'

# %%
data = {}
stock = yf.Ticker("ABB.NS")
m_cap = stock.info.get('marketCap')
sector = stock.info.get("sector")
data["ABB.NS"] = m_cap,sector

# %%
m_cap
# Out:
# 1158782255104

# %%
data
# Out:
# {'ABB.NS': (1158782255104, 'Industrials')}

# %%
pd.DataFrame(data)
# Out:
#           ABB.NS
# 0  1158782255104
# 1    Industrials

# %%
stock.info
# Out:
# {'address1': 'Plot No. 5 & 6, 2nd Stage',
#  'address2': 'Disha - 3rd Floor Peenya Industrial Area IV Peenya',
#  'city': 'Bengaluru',
#  'zip': '560058',
#  'country': 'India',
#  'phone': '91 80 2294 9150',
#  'fax': '91 80 2294 9148',
#  'website': 'https://new.abb.com/indian-subcontinent',
#  'industry': 'Specialty Industrial Machinery',
#  'industryKey': 'specialty-industrial-machinery',
#  'industryDisp': 'Specialty Industrial Machinery',
#  'sector': 'Industrials',
#  'sectorKey': 'industrials',
#  'sectorDisp': 'Industrials',
# ...

# %%
data = {}
stock = yf.Ticker("3MINDIA.NS")
m_cap = stock.info.get('marketCap')
sector = stock.info.get("sector")
data["3MINDIA.NS"] = m_cap,sector

# %%
data
# Out:
# {'3MINDIA.NS': (388532273152, 'Industrials')}
