# %% [markdown]
# ### Here the data will be fetched and pushed to SQL database

# %%
pip install sqlalchemy psycopg2-binary
# Out:
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.7 MB 2.9 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.7 MB 2.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.6/2.7 MB 2.2 MB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.7 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 2.1 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipython-sql
# Out:
# ...
#
#    ---------------------------------------- 0/4 [ipython-genutils]
#    ---------------------------------------- 0/4 [ipython-genutils]
#    ---------------------------------------- 0/4 [ipython-genutils]
#    ---------------------------------------- 0/4 [ipython-genutils]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    -------------------- ------------------- 2/4 [prettytable]
#    ------------------------------ --------- 3/4 [ipython-sql]
# ...

# %%
pip install vaderSentiment
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
## Importer
import numpy as np
import pandas as pd
import yfinance as yf
import time
from sqlalchemy import create_engine,text
from datetime import datetime, timedelta
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import os
from dotenv import load_dotenv

## Fetching credentials from env for DataBase
load_dotenv() ## Create ur own env file

DB_USER = os.getenv("DB_USER")
DB_PASS = os.getenv("DB_PASS")
DB_HOST = os.getenv("DB_HOST")
DB_PORT = os.getenv("DB_PORT")
DB_NAME = os.getenv("DB_NAME")

db = f'postgresql://{DB_USER}:{DB_PASS}@{DB_HOST}:{DB_PORT}/{DB_NAME}' ## Replace ur password
engine = create_engine(db)
analyzer = SentimentIntensityAnalyzer()

# %%
## To push the dimensional table details (i.e) Stocks basic details

df = pd.read_csv(r"C:\Users\ilaky\Documents\DataScience\AI-Driven_Multi-Asset-Intelligence_&_Portfolio-Engine\data\fetched_stocks.csv")

def dimens_data_push(df,engine):
    df.columns = ['ticker', 'company_name', 'sector', 'industry', 
        'market_cap_cat', 'cap_value']
    try:
        df.to_sql("dimens_assets_details",engine,if_exists ="append",index= False)
        print("Data has been sucessfully pushed to SQL")
    except Exception as e:
        print(f"Error {e}")
        
with engine.connect() as conn:
    conn.execute(text("TRUNCATE TABLE dimens_assets_details CASCADE;"))
    conn.commit()
    #print("Table truncated. Structure preserved.")
    
dimens_data_push(df,engine)
# Out:
# Data has been sucessfully pushed to SQL

# %%
## Fetch the fundamental and financial detials of the random sample from SQL
## To not replace the list again, creating a separate section for fundamental fetching

def fundamental_fetcher(engine):
    query = "Select asset_id,ticker from sample_set_100;"
    with engine.connect() as con:
        sample_df = pd.read_sql(query,con)
    with engine.begin() as conn:
        conn.execute(text("Delete from fact_fundamentals;")) ## Cleaing the old data

    fundamentals_data = []
    print("Starting process")
    for row in sample_df.itertuples(index=False):
        stock_ticker = row.ticker
        as_id = row.asset_id

        try:
            stock = yf.Ticker(stock_ticker)
            info = stock.info

            pe = info.get("trailingPE")
            peg = info.get("pegRatio")
            pb = info.get("priceToBook")
            earn_growth = info.get("earningsGrowth")
            roe =  info.get("returnOnEquity")
            raw_de = info.get("debtToEquity")
                
            adj_de = (raw_de/100)  ## Converting to right format
            ## PEG & ROE is not available for some stocks,so we will calculate manually
            if roe is None and pe and pb and pe > 0:
                roe_cal = pb/pe
            else:
                roe_cal = roe
            
            if peg is None and pe and earn_growth and earn_growth != 0:
                peg = pe / (earn_growth * 100)

            fundamentals_data.append({
                "asset_id" : as_id,
                "pe_ratio" : pe,
                "peg_ratio" : peg,
                "roe_percent" : roe_cal,
                "gross_profits" : info.get("grossProfits"),
                "revenue_growth" : info.get("revenueGrowth"),
                "earnings_growth" : earn_growth,
                "operating_margins" : info.get("operatingMargins"),
                "ebita_margins" : info.get("ebitdaMargins"),
                "debt_to_equity" : adj_de,
                "institutional_held_percent" : info.get("heldPercentInstitutions"),
                "fifty_two_week_change" : info.get("52WeekChange")
            })

            #print(f"Fetching Done till : {stock_ticker}")

        except Exception as e:
            print(f"Failed {stock_ticker} due to error {e}")

        time.sleep(0.2)

    fundamental_df = pd.DataFrame(fundamentals_data)
    fundamental_df.to_sql("fact_fundamentals",engine,if_exists="append",index =False)
    print("Fundamental data is pushed SQL")

fundamental_fetcher(engine)
# Out:
# Starting process
# Fundamental data is pushed SQL

# %%
## Fetch the price history of the sample 100 stocks.
## To not replace the list again, creating a separate section.

# %%
def fetch_price_history(engine):
    query = "Select asset_id,ticker from sample_set_100;"
    with engine.connect() as con:
        sample_df = pd.read_sql(query,con)
    with engine.begin() as conn:
        conn.execute(text("Delete from fact_prices;")) ## Cleaing the old data

    all_prices = []
    for row in sample_df.itertuples(index=False):
        stock_ticker = row.ticker
        asset_id = row.asset_id

        try:
            stock = yf.Ticker(stock_ticker)
            hist = stock.history(period="1y")

            if hist.empty:
                print(f"Data not found for {stock_ticker}")
                continue
                
            hist = hist.reset_index()

            for price_row in hist.itertuples():
                all_prices.append({
                    "asset_id" : asset_id,
                    "trade_date" : price_row.Date.date(), ## Converting to date format
                    "close_price" : price_row.Close,
                    "volume" : price_row.Volume
                })

        except Exception as e:
            print(f"Error fetching data in {stock_ticker} : {e}")

        time.sleep(0.1)

        if all_prices:
            prices_df = pd.DataFrame(all_prices)
             ## Drop duplicates...if any
            prices_df = prices_df.drop_duplicates(subset=["asset_id","trade_date"])

            try:
                prices_df.to_sql("fact_prices",engine,if_exists="append",index=False,method="multi",chunksize=5000)
                ##print(f"\nSuccess : {len(prices_df)} price records pushed to SQL")

            except Exception as e:
                print(f"Database load error {e}")
        else:
            print("No price data collected")
    print("Data is successfully pushed to SQL")

fetch_price_history(engine)
# Out:
# Data is successfully pushed to SQL

# %%
## Scrape the NEWS / Headlines of the sample 100 stocks for Sentiment Analysis --> yfinance api

def fetch_news_sentiment(engine):
    query="Select asset_id, ticker from sample_set_100;"
    with engine.connect() as con:
        sample_df = pd.read_sql(query,con)
    

        news_data = []
        print(f"Process starting for {len(sample_df)} of stocks")

        for row in sample_df.itertuples(index=False):
            stock_ticker = row.ticker
            asset_id = row.asset_id

            try:
                stock = yf.Ticker(stock_ticker)
                news_info = stock.news

                if not news_info:
                    continue
                for items in news_info[:2]: ## I am taking only latest 2 news
                    content = items.get("content", {})
                    title = content.get("title", "")
                    summary = content.get("summary", "")
                    
                    combined_data = f"{title} . {summary}"
                    sentiment_dict = analyzer.polarity_scores(combined_data)
                    sentiment_score = sentiment_dict["compound"]

                    news_data.append({
                        "asset_id" : asset_id,
                        "sentiment_score" : sentiment_score,
                        "news_summary" : combined_data[:1000] ## Adding Limit to not get more data 
                    })
               # print(f"News fetched for {stock_ticker}")
            except Exception as e:
                print(f"Failed to fetch news for {stock_ticker} : {e}")

            time.sleep(0.5)

        if news_data:
            news_df = pd.DataFrame(news_data)
            news_df = news_df.drop_duplicates(subset=["asset_id", "news_summary"])
        
            news_to_push = news_df 

            with engine.connect() as con:
                existing_news = pd.read_sql("SELECT asset_id, news_summary FROM fact_news", con)

        
            if not existing_news.empty:
                merged_df = news_df.merge(existing_news, on=["asset_id", "news_summary"], how="left", indicator=True)
                news_to_push = merged_df[merged_df["_merge"] == "left_only"].drop(columns=["_merge"])
                #print("Not 1 executed") -- testing
        
        # 4. FINAL PUSH
            if not news_to_push.empty:
                news_to_push.to_sql('fact_news', engine, if_exists='append', index=False)
                print(f"\nSuccess: {len(news_to_push)} new records pushed to SQL.")
            else:
                print("\nNo new news items found since last run.")
        else:
            print("News details not found.")

fetch_news_sentiment(engine)
# Out:
# Process starting for 100 of stocks
#
# Success: 144 new records pushed to SQL.

# %%
# The Anchor 50 Automated Update
update_ranking = """
create or replace view stock_scoring as
with fundamental_adj as (
select fa.asset_id,
COALESCE(case when fa.peg_ratio<=0 then 99 else fa.peg_ratio end,99) as adj_peg,
coalesce(fa.roe_percent,0) as adj_roe_percent,
coalesce(fa.debt_to_equity,5) as adj_debt_to_equity
from fact_fundamentals fa
),
sentiment_avg as(
select asset_id,
avg(sentiment_score) as avg_senti_score
from fact_news n
group by asset_id
)

select  d.asset_id,d.ticker,d.company_name,
		d.sector, d.industry,d.market_cap_cat,
		f.adj_peg,f.adj_roe_percent,
		f.adj_debt_to_equity,
		coalesce(s.avg_senti_score,0) as adj_senti_score , -- score range from -1 to 1

		rank() over (order by f.adj_peg asc) as peg_rank,
		rank() over (order by f.adj_roe_percent desc) as roe_rank,
		rank() over (order by f.adj_debt_to_equity asc) as de_rank,
		rank() over (order by coalesce(avg_senti_score,0) desc) as sentimental_rank
 
from sample_set_100 d left join fundamental_adj f
on d.asset_id = f.asset_id
left join sentiment_avg s 
on d.asset_id = s.asset_id;

"""

create_anchor_query = """
drop table if exists anchor_50;

create table anchor_50 as
select asset_id,
		ticker,
		company_name,
		sector,
		market_cap_cat,
		adj_senti_score,
		(peg_rank+roe_rank+de_rank+sentimental_rank) as total_sentiment_score
from stock_scoring 
order by total_sentiment_score ASC
limit 50;
"""

update_dimensional_table="""
update dimens_assets_details
set is_anchor = case
when ticker in (select ticker from anchor_50) then True
else False end ;"""

update_sample_set_100 = """
update sample_set_100
set is_anchor = case
when ticker in (select ticker from anchor_50) then True
else False end;
"""

with engine.begin() as conn:
    print("Updateing the ranking view...")
    conn.execute(text(update_ranking))
    print("Anchor_50 table with the ranks...")
    conn.execute(text(create_anchor_query))
    print("updating Anchor 50 flags in dimensional_table")
    conn.execute(text(update_dimensional_table))
    print("updating Anchor 50 flags in sample_set_table")
    conn.execute(text(update_sample_set_100))
    print("SUCCESS: Anchor list is perfectly synced with the latest data.")
# Out:
# Updateing the ranking view...
# Anchor_50 table with the ranks...
# updating Anchor 50 flags in dimensional_table
# updating Anchor 50 flags in sample_set_table
# SUCCESS: Anchor list is perfectly synced with the latest data.

# %%
st= yf.Ticker("BHARTIARTL.NS")

# %%
st.info
# Out:
# {'address1': 'Bharti Crescent',
#  'address2': '1 Nelson Mandela Road Vasant Kunj Phase II',
#  'city': 'New Delhi',
#  'zip': '110070',
#  'country': 'India',
#  'phone': '91 11 4666 6100',
#  'fax': '91 11 4166 6137',
#  'website': 'https://www.airtel.in',
#  'industry': 'Telecom Services',
#  'industryKey': 'telecom-services',
#  'industryDisp': 'Telecom Services',
#  'sector': 'Communication Services',
#  'sectorKey': 'communication-services',
#  'sectorDisp': 'Communication Services',
# ...
