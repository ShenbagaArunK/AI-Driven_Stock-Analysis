# %% [markdown]
# ## Here we will be fetching the data and connect APIs

# %%
pip install sqlalchemy psycopg2-binary
# Out:
# Requirement already satisfied: sqlalchemy in d:\data_softwares\lib\site-packages (2.0.43)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.11-cp313-cp313-win_amd64.whl.metadata (5.1 kB)
# Requirement already satisfied: greenlet>=1 in d:\data_softwares\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\data_softwares\lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading psycopg2_binary-2.9.11-cp313-cp313-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.7 MB 2.9 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.7 MB 2.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.6/2.7 MB 2.2 MB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.7 MB 2.2 MB/s eta 0:00:01
#    -------------------------------------- - 2.6/2.7 MB 2.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 2.1 MB/s  0:00:01
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.11
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipython-sql
# Out:
# Collecting ipython-sql
#   Downloading ipython_sql-0.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting prettytable (from ipython-sql)
#   Downloading prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: ipython in d:\data_softwares\lib\site-packages (from ipython-sql) (9.7.0)
# Requirement already satisfied: sqlalchemy>=2.0 in d:\data_softwares\lib\site-packages (from ipython-sql) (2.0.43)
# Collecting sqlparse (from ipython-sql)
#   Downloading sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: six in d:\data_softwares\lib\site-packages (from ipython-sql) (1.17.0)
# Collecting ipython-genutils (from ipython-sql)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Requirement already satisfied: greenlet>=1 in d:\data_softwares\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\data_softwares\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: colorama>=0.4.4 in d:\data_softwares\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in d:\data_softwares\lib\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in d:\data_softwares\lib\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in d:\data_softwares\lib\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in d:\data_softwares\lib\site-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in d:\data_softwares\lib\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in d:\data_softwares\lib\site-packages (from ipython->ipython-sql) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in d:\data_softwares\lib\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in d:\data_softwares\lib\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in d:\data_softwares\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in d:\data_softwares\lib\site-packages (from jedi>=0.18.1->ipython->ipython-sql) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in d:\data_softwares\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in d:\data_softwares\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure_eval in d:\data_softwares\lib\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (0.2.3)
# Downloading ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Downloading prettytable-3.17.0-py3-none-any.whl (34 kB)
# Downloading sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Installing collected packages: ipython-genutils, sqlparse, prettytable, ipython-sql
#
#    ---------------------------------------- 0/4 [ipython-genutils]
#    ---------------------------------------- 0/4 [ipython-genutils]
#    ---------------------------------------- 0/4 [ipython-genutils]
#    ---------------------------------------- 0/4 [ipython-genutils]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    ---------- ----------------------------- 1/4 [sqlparse]
#    -------------------- ------------------- 2/4 [prettytable]
#    ------------------------------ --------- 3/4 [ipython-sql]
#    ------------------------------ --------- 3/4 [ipython-sql]
#    ---------------------------------------- 4/4 [ipython-sql]
#
# Successfully installed ipython-genutils-0.2.0 ipython-sql-0.5.0 prettytable-3.17.0 sqlparse-0.5.5
# Note: you may need to restart the kernel to use updated packages.

# %%
## Importer
import numpy as np
import pandas as pd
import yfinance as yf
import time
from sqlalchemy import create_engine,text
from datetime import datetime, timedelta

key = "sql_12345"
db = f'postgresql://postgres:{key}@localhost:5432/stock_analysis_db' ## Replace ur password
engine = create_engine(db)

# %%
## To push the dimensional table details (i.e) Stocks basic details

df = pd.read_csv(r"C:\Users\ilaky\Documents\DataScience\AI-Driven_Multi-Asset-Intelligence_&_Portfolio-Engine\data\fetched_stocks.csv")

def dimens_data_push(df,engine):
    df.columns = ['ticker', 'company_name', 'sector', 'industry', 
        'market_cap_cat', 'cap_value']
    try:
        df.to_sql("dimens_assets_details",engine,if_exists ="append",index= False)
        print("Data has been sucessfully pushed to SQL")
    except Exception as e:
        print(f"Error {e}")
        
with engine.connect() as conn:
    conn.execute(text("TRUNCATE TABLE dimens_assets_details CASCADE;"))
    conn.commit()
    #print("Table truncated. Structure preserved.")
    
dimens_data_push(df,engine)
# Out:
# Data has been sucessfully pushed to SQL

# %%
## Fetch the fundamental and financial detials of the random sample from SQL
## To not replace the list again, creating a separate section for fundamental fetching

def fundamental_fetcher(engine):
    query = "Select asset_id,ticker from sample_set_100;"
    with engine.connect() as con:
        sample_df = pd.read_sql(query,con)

    fundamentals_data = []
    print("Starting process")
    for row in sample_df.itertuples(index=False):
        stock_ticker = row.ticker
        as_id = row.asset_id

        try:
            stock = yf.Ticker(stock_ticker)
            info = stock.info

            pe = info.get("trailingPE")
            peg = info.get("pegRatio")
            pb = info.get("priceToBook")
            earn_growth = info.get("earningsGrowth")
            roe =  info.get("returnOnEquity")
                ## PEG & ROE is not available for some stocks,so we will calculate manually
            if roe is None and pe and pb and pe > 0:
                roe_cal = pb/pe
            else:
                roe_cal = roe
            
            if peg is None and pe and earn_growth and earn_growth != 0:
                peg = pe / (earn_growth * 100)

            fundamentals_data.append({
                "asset_id" : as_id,
                "pe_ratio" : pe,
                "peg_ratio" : peg,
                "roe_percent" : roe_cal,
                "gross_profits" : info.get("grossProfits"),
                "revenue_growth" : info.get("revenueGrowth"),
                "earnings_growth" : earn_growth,
                "operating_margins" : info.get("operatingMargins"),
                "ebita_margins" : info.get("ebitdaMargins"),
                "debt_to_equity" : info.get("debtToEquity"),
                "institutional_held_percent" : info.get("heldPercentInstitutions"),
                "fifty_two_week_change" : info.get("52WeekChange")
            })

            #print(f"Fetching Done till : {stock_ticker}")

        except Exception as e:
            print(f"Failed {stock_ticker} due to error {e}")

        time.sleep(0.2)

    fundamental_df = pd.DataFrame(fundamentals_data)
    fundamental_df.to_sql("fact_fundamentals",engine,if_exists="replace",index =False)
    print("Fundamental data is pushed SQL")

fundamental_fetcher(engine)
# Out:
# Starting process
# Fundamental data is pushed SQL

# %%
stock = yf.Ticker("ADANIPOWER.NS")

# %%
pe = stock.info.get("trailingPE")
earn_growth = stock.info.get("earningsGrowth")

# %%
peg= pe / (earn_growth * 100)
peg
# Out:
# -1.6032914465408805

# %%
stock.info
# Out:
# {'address1': 'Adani Corporate House',
#  'address2': 'Shantigram Near Vaishno Devi Circle S. G. Highway, Khodiyar',
#  'city': 'Ahmedabad',
#  'zip': '382421',
#  'country': 'India',
#  'phone': '91 79 2656 7555',
#  'fax': '91 79 2555 7177',
#  'website': 'https://www.adanipower.com',
#  'industry': 'Utilities - Independent Power Producers',
#  'industryKey': 'utilities-independent-power-producers',
#  'industryDisp': 'Utilities - Independent Power Producers',
#  'sector': 'Utilities',
#  'sectorKey': 'utilities',
#  'sectorDisp': 'Utilities',
#  'longBusinessSummary': 'Adani Power Limited engages in the generation, transmission, and sale of electricity under long term power purchase agreements (PPAs), supplemental PPAs, medium and short term PPAs, and on merchant basis in India. The company generates electricity through thermal energy sources through various power projects with a combined installed and commissioned capacity of 17,550 megawatt (MW). It also operates various coal based power plants comprising 4,620 MW at Mundra, Gujarat; 3,300 MW at Tiroda, Maharashtra; 1,320 MW at Kawai, Rajasthan; 1,200 MW at Udupi, Karnataka; 600 MW at Raigarh and Korba, Chhattisgarh; 1,370 MW at Raipur, Chhattisgarh; 1,200 MW at Mahan, Madhya Pradesh; 1,200 MW at Mutiara, Tamil Nadu; 1,600 MW at Mirzapur, Uttar Pradesh; 500MW at Dahanu, Maharashtra; and 1600 MW at Godda, Jharkhand. The company also operates solar based power plant comprising 40 MW at Bitta, Gujarat. In addition, it engages in coal import and supply/trading business. Adani Power Limited was founded in 1988 and is headquartered in Ahmedabad, India.',
#  'fullTimeEmployees': 4176,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Gautambhai Shantilal Adani S.Y. B.Com',
#    'age': 63,
#    'title': 'Founder & Non-Executive Non-Independent Chairman',
#    'yearBorn': 1962,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Shersingh B. Khyalia',
#    'age': 59,
#    'title': 'CEO & Whole-time Director',
#    'yearBorn': 1966,
#    'fiscalYear': 2025,
#    'totalPay': 91600000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Dilip Kumar Jha',
#    'title': 'Chief Financial Officer',
#    'fiscalYear': 2025,
#    'totalPay': 28800000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Deepak S. Pandya',
#    'title': 'Company Secretary & Compliance Officer',
#    'fiscalYear': 2025,
#    'totalPay': 7300000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Anil Kumar Sardana AICWA, B.E., PGDBM',
#    'age': 66,
#    'title': 'MD & Executive Director',
#    'yearBorn': 1959,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Rajiv Kumar Rustagi',
#    'age': 62,
#    'title': 'Vice President of Finance & Accounts',
#    'yearBorn': 1963,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Nishit  Dave',
#    'title': 'Head of Investor Relations',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Amitabh  Mishra',
#    'title': 'Chief Human Resources Officer',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'compensationAsOfEpochDate': 1767139200,
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 150.91,
#  'open': 150.47,
#  'dayLow': 148.95,
#  'dayHigh': 150.75,
#  'regularMarketPreviousClose': 150.91,
#  'regularMarketOpen': 150.47,
#  'regularMarketDayLow': 148.95,
#  'regularMarketDayHigh': 150.75,
#  'payoutRatio': 0.0,
#  'beta': 0.132,
#  'trailingPE': 25.492334,
#  'forwardPE': 21.967117,
#  'volume': 5053518,
#  'regularMarketVolume': 5053518,
#  'averageVolume': 16047845,
#  'averageVolume10days': 25501503,
#  'averageDailyVolume10Day': 25501503,
#  'bid': 149.62,
#  'ask': 149.76,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 2885963481088,
#  'fiftyTwoWeekLow': 92.4,
#  'fiftyTwoWeekHigh': 182.7,
#  'allTimeHigh': 182.7,
#  'allTimeLow': 3.03,
#  'priceToSalesTrailing12Months': 5.319275,
#  'fiftyDayAverage': 142.6272,
#  'twoHundredDayAverage': 133.30615,
#  'trailingAnnualDividendRate': 0.0,
#  'trailingAnnualDividendYield': 0.0,
#  'currency': 'INR',
#  'tradeable': False,
#  'enterpriseValue': 3293910401024,
#  'profitMargins': 0.21112,
#  'floatShares': 5216536560,
#  'sharesOutstanding': 19284694705,
#  'heldPercentInsiders': 0.71873003,
#  'heldPercentInstitutions': 0.17778999,
#  'impliedSharesOutstanding': 19286043380,
#  'bookValue': 30.287,
#  'priceToBook': 4.9407334,
#  'lastFiscalYearEnd': 1743379200,
#  'nextFiscalYearEnd': 1774915200,
#  'mostRecentQuarter': 1767139200,
#  'earningsQuarterlyGrowth': -0.189,
#  'netIncomeToCommon': 109792698368,
#  'trailingEps': 5.87,
#  'forwardEps': 6.812,
#  'lastSplitFactor': '5:1',
#  'lastSplitDate': 1758499200,
#  'enterpriseToRevenue': 6.071,
#  'enterpriseToEbitda': 16.439,
#  '52WeekChange': 0.51470447,
#  'SandP52WeekChange': 0.13519716,
#  'quoteType': 'EQUITY',
#  'currentPrice': 149.64,
#  'targetHighPrice': 187.0,
#  'targetLowPrice': 173.0,
#  'targetMeanPrice': 182.16667,
#  'targetMedianPrice': 184.5,
#  'recommendationMean': 1.16667,
#  'recommendationKey': 'strong_buy',
#  'numberOfAnalystOpinions': 6,
#  'totalCash': 103412097024,
#  'totalCashPerShare': 5.38,
#  'ebitda': 200368324608,
#  'totalDebt': 484636884992,
#  'totalRevenue': 542548295680,
#  'debtToEquity': 81.251,
#  'revenuePerShare': 28.83,
#  'grossProfits': 234120593408,
#  'earningsGrowth': -0.159,
#  'revenueGrowth': -0.089,
#  'grossMargins': 0.43152002,
#  'ebitdaMargins': 0.36931,
#  'operatingMargins': 0.24919,
#  'financialCurrency': 'INR',
#  'symbol': 'ADANIPOWER.NS',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Free Realtime Quote',
#  'triggerable': True,
#  'customPriceAlertConfidence': 'HIGH',
#  'corporateActions': [],
#  'regularMarketTime': 1770881400,
#  'exchange': 'NSI',
#  'messageBoardId': 'finmb_37293443',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'exchangeTimezoneShortName': 'IST',
#  'gmtOffSetMilliseconds': 19800000,
#  'market': 'in_market',
#  'esgPopulated': False,
#  'marketState': 'REGULAR',
#  'shortName': 'ADANI POWER LTD',
#  'longName': 'Adani Power Limited',
#  'earningsTimestamp': 1769680800,
#  'earningsTimestampStart': 1777456800,
#  'earningsTimestampEnd': 1777456800,
#  'earningsCallTimestampStart': 1769686200,
#  'earningsCallTimestampEnd': 1769686200,
#  'isEarningsDateEstimate': True,
#  'epsTrailingTwelveMonths': 5.87,
#  'epsForward': 6.812,
#  'epsCurrentYear': 5.772,
#  'priceEpsCurrentYear': 25.925156,
#  'fiftyDayAverageChange': 7.012802,
#  'fiftyDayAverageChangePercent': 0.049168758,
#  'twoHundredDayAverageChange': 16.333847,
#  'twoHundredDayAverageChangePercent': 0.12252883,
#  'sourceInterval': 15,
#  'exchangeDataDelayedBy': 15,
#  'averageAnalystRating': '1.2 - Strong Buy',
#  'cryptoTradeable': False,
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 1250739900000,
#  'regularMarketChange': -1.2700043,
#  'regularMarketDayRange': '148.95 - 150.75',
#  'fullExchangeName': 'NSE',
#  'averageDailyVolume3Month': 16047845,
#  'fiftyTwoWeekLowChange': 57.239998,
#  'fiftyTwoWeekLowChangePercent': 0.6194805,
#  'fiftyTwoWeekRange': '92.4 - 182.7',
#  'fiftyTwoWeekHighChange': -33.059998,
#  'fiftyTwoWeekHighChangePercent': -0.18095237,
#  'fiftyTwoWeekChangePercent': 51.470448,
#  'regularMarketChangePercent': -0.841564,
#  'regularMarketPrice': 149.64,
#  'trailingPegRatio': None}
